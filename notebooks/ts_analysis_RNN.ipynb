# %% [markdown]
# **Connect Google Collab with G-drive**

# %%
from google.colab import drive
import os

drive.mount('/content/drive/')
os.getcwd()

path = '/content/drive/My Drive/github_projects/time_series_analysis'
os.chdir(path)
os.listdir(path)
# Out:
# Mounted at /content/drive/
# ['.git',
#  'data',
#  'reports',
#  'src',
#  'notebooks',
#  'references',
#  'models',
#  'docs',
#  'README.md',
#  'tox.ini',
#  'Makefile',
#  'test_environment.py',
#  '.env',
#  'requirements.txt',
#  'LICENSE',
#  'setup.py',
#  'previous_files',
#  '.gitignore']
